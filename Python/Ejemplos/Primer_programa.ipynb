# %% [markdown]
# # Título:
# ## Título
# ### Título

# %%
print("Hola Mundo")
print("Hola universo")
# Out:
# Hola Mundo
# Hola universo

# %%
ciudad= "Medellín"
universidad = "EIA"
Semestre = 2
print(ciudad, universidad, Semestre)
# Out:
# Medellín EIA 2

# %% [markdown]
# ## Tipos de datos
# - int
# - float
# - string
# - bool

# %% [markdown]
# ## Operadores aritméticos
# - suma: +
# - resta: -
# - multiplicación: *
# - división: /
# - división entera: //
# - residuo: %
# - potencia: **
# - multiplicación de matrices: &

# %%
a=10
b=3
print(a//b)
print(a%b)
# Out:
# 3
# 1

# %% [markdown]
# ## Operadores de comparación
# - <, >
# - ==
# - !=

# %% [markdown]
# ## Entrada y salida de datos

# %%
nombre = input()
print("Ingrese su nombre: ")
print(nombre)
# Out:
# Ingrese su nombre:
# juan

# %%
nombre=input("Ingrese su nombre: ")
edad=input("Ingrese su edad: ")
ciudad=input("Ingrese su ciudad: ")
print(nombre)
print(edad)
print(ciudad)
# Out:
# juan

# %% [markdown]
# Escriba un programa que muestre un mensaje de bienvenida, utilizando al menos cuatro instrucciones print
#
# cree variables para almacenar su nombre, carrera, semestre y promedio e imprima
#
# Solicite el nombre del usuario y saludelo con un mensaje personalizado
#
# solicite dos numero enteros y calcule la suma, resta, multiplicacion y division
#
# solicite el radio de un circulo y calcule diametro, perimetro y area

# %%
print("Bienvenido de vuelta. ")
print("Estuviste ausente durante 5 días. ")
print("Mientras estuviste por fuera tus minas de chocolate han generado 500 Toneladas de galletas.")
print("¿Deseas seguir recolectando galletas?")
# Out:
# Bienvenido de vuelta.
# Estuviste ausente durante 5 días.
# Mientras estuviste por fuera tus minas de chocolate han generado 500 Toneladas de galletas.
# ¿Deseas seguir recolectando galletas?

# %%
nombre= input()
carrera=input()
semestre= input()
promedio_acumulado= input()
print("Ingrese su nombre:",nombre)
print("Ingrese su carrera:",carrera)
print("Ingrese su semestre:",semestre)
print("Ingrese su promedio_acumulado:",promedio_acumulado)
# Out:
# Ingrese su nombre: santiago
# Ingrese su carrera: fisica
# Ingrese su semestre: 2
# Ingrese su promedio_acumulado: 4

# %%
nombre=input()
print("Ingrese su nombre:",nombre)
mensaje= f"Buenas tardes {nombre} puede avanzar a la siguiente sala"
print()
print(mensaje)
# Out:
# Ingrese su nombre: juan
# Buenas tardes juan puede avanzar a la siguiente sala

# %%
print("Ingrese dos números enteros a y b.")
print("a: ")
a=input()
a1=int(a)
print("b: ")
b=input()
b1=int(b)
print(int(a1+b1))
print(int(a1-b1))
print(int(a1*b1))
print(int(a1/b1))
# Out:
# Ingrese dos números enteros a y b.
# a:
# b:
# 3
# 1
# 2
# 2

# %%
print("El programa calculará por usted lo siguiente: diámetro, perímetro y área.")
print("Introduzca cualquier radio de un círculo r: ")
print("r: ")
r=float(input())
print("Este es el radio:", (3.1416*(r**2)))
print("Este es el perímetro:", (3.1416*r*2))
print("Este es el diámetro:", (r*2))
# Out:
# El programa calculará por usted lo siguiente: diámetro, perímetro y área.
# Introduzca cualquier radio de un círculo r:
# r:
# Este es el radio: 3.1416
# Este es el perímetro: 6.2832
# Este es el diámetro: 2.0

# %% [markdown]
# Type Casting

# %%
print(str(10))
print(float(10))
print(int(10))
print(bool(10))
print(bool(0)) #Todos los valores númericos diferentes de cero son "True"
print(bool("Hola"))
print(type(bool(10)))
# Out:
# 10
# 10.0
# 10
# True
# False
# True
# <class 'bool'>

# %%
num="25"
resul= int(num) + 14
print(resul)
# Out:
# 39

# %%
num="25.6"
#resul= int(num) Es importante asignar los tipos correctos a la hora de cambiar tipos
resul= int(float(num)) #Da la parte entera del float
print(resul)
# Out:
# 25

# %%
# edad=20 Asigna un valor a una variable
# edad==20 compara
edad
edad==0
print(edad)
# Out:
# 0

# %% [markdown]
# Los operadores aritmeticos Python los clasifica según PEMDAS.
# Los operadores lógicos según expresión por expresión y al final los operadores comparativos (and,or not(invierte el valor bool de una variable))

# %%
num=34.2
print(round(num))
# Out:
# 34

# %%
#len (longitud en un string)
si="Hola adios"
print(len(si))
# Out:
# 10

# %%
#max y min (verifica maximos y minimos en lista)
jaja=[2,3,4,67,8]
print(max(jaja))
print(min(jaja))
# Out:
# 67
# 2

# %% [markdown]
# #### Buenas prácticas

# %% [markdown]
# * NO colocar nombres ambiguos para las variables
# * NO repetir las mismas líneas de códigos (prints de un mismo texto por ejemplo)
# * Separar las partes del código (sobre todo para códigos largos). Si se quiere se pueden separar en: "Entrada"-"Procesamiento"-"Salida"
