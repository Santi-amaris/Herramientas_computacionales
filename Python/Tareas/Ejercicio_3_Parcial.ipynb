# %% [markdown]
# #### $\color{LightSalmon}{\underline{\textbf{Ejercicio 3 --- Sistema de clasificación de estudiantes}}}$

# %%
#Entrada de datos 
nom_est= input("Ingrese el nombre del estudiante: ",)
edad_est= input("Ingrese la edad del estudiante: ",)
prom_est= float(input("Ingrese el promedio académico del estudiante: ",))
num_materias_apro= int(input("Ingrese el número de materias aprobadas:",))
matri_acti= input("¿Tiene matrícula activa? (S/N):")
deuda_pend= input("¿Tiene deuda pendiente? (S/N)",)

#Procesamiento de datos
if (0<edad_est<18):
    resul_edad="Estudiante menor de edad"
    Bandera=True
elif(edad_est>18):
    resul_edad="Estudiante mayor de edad"
    Bandera=True
else:
    resul_edad="Error"
    Bandera=False

if(num_materias_apro>=0):
    Bandera=True
elif (num_materias_apro<0):
    Bandera=False

if(0.0<=prom_est<=5.0):
    Bandera=True
else:
    Bandera=False


if (matri_acti=="S" or matri_acti=="s"):
    matri_acti=True
elif (matri_acti=="N" or matri_acti=="n"):
    matri_acti=False
else:
    matri_acti=False


if (deuda_pend=="S" or deuda_pend=="s"):
    deuda_pend=True
elif (deuda_pend=="N" or deuda_pend=="n"):
    deuda_pend=False
else:
    deuda_pend=False

if (((matri_acti==True) and (deuda_pend==False) and (prom_est>=3.5) and (num_materias_apro>=4))):
    print("Nombre del estudiante: ", nombre_est)
    print("--------------------------")
    print("Edad del estudiante: ", edad_est)
    print("--------------------------")
    print("El promedio académico del estudiante es:",prom_est)
    print("--------------------------")
    print("El número de materias aprobadas:", num_materias_apro)
    print("--------------------------")
    print("¿Tiene matrícula activa?:", matri_acti)
    print("--------------------------")
    print("¿Tiene deuda pendiente?", deuda_pend)
    print("--------------------------")
    print("Acceso completo")
elif (((matri_acti==True) and (not((deuda_pend==False) and (prom_est>=3.5) and (num_materias_apro>=4))))):
    print("Acceso restringido")
